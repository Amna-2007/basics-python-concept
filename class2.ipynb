# %%
print("string")
# Out:
# string

# %% [markdown]
# ### variables

# %%
name = "Amna kabeer"
print(name)
# Out:
# Amna kabeer

# %%
type(name)
# Out:
# str

# %%
id(name)
# Out:
# 2097254553136

# %% [markdown]
# ### Datatypes

# %% [markdown]
# - Number --> Integers eg: 34
# - Decimal --> Float eg: 34.7
# - Character/Alphabets --> String eg: "Amna kabeer"
# - Binary 1/0 OR True or False --> Boolean eg: True / False

# %%
number = 3000

# %%
print(number)
# Out:
# 3000

# %%
type(number)
# Out:
# int

# %%
id(number)
# Out:
# 2097254049584

# %%
weight = 46.7
print(weight)
# Out:
# 46.7

# %%
type(weight)
# Out:
# float

# %%
id(weight)
# Out:
# 2097249421392

# %%
name = "Amna kabeer"
print(name)
# Out:
# Amna kabeer

# %%
type(name)
# Out:
# str

# %%
id(name)
# Out:
# 2097254751280

# %%
boolean_var = True
print(boolean_var)
# Out:
# True

# %%
type(boolean_var)
# Out:
# bool

# %%
id(boolean_var)
# Out:
# 140734854114048

# %% [markdown]
# ### Operators

# %% [markdown]
# - Addition
# - Subtractiom
# - Multiplication
# - Division
# - Power

# %%
2+4
# Out:
# 6

# %%
4-4
# Out:
# 0

# %%
3*4
# Out:
# 12

# %%
3**3
# Out:
# 27

# %%
6/2
# Out:
# 3.0

# %% [markdown]
# ### Assignment and markdown guide

# %% [markdown]
# - point 1
# - point 2
# - point 3
#
# 1. number 1
# 2. number 2
# 3. number 3
#
# To save file press--> CTRL+S

# %%
str_variable = "Amna kabeer"
print(str_variable)
# Out:
# Amna kabeer

# %% [markdown]
# ### unfamiliar operator
#
# - remainder%
# - floor//

# %%
#3*6 = 18
#3*7 = 27
20 % 3
# Out:
# 2

# %%
13%4
# Out:
# 1

# %%
13/4
# Out:
# 3.25

# %%
20//3
# Out:
# 6

# %%
26//5
# Out:
# 5

# %% [markdown]
# ### Expression (BODMAS)

# %%
((5*6) + (4-2)) - 5
#(30 + 2) - 5
#32-5
#27
# Out:
# 27

# %%
((((4*2)+2)/5)*3) + 1

#(((8)+2/5)*3)+1
#((10/5)*3)+1
#(2*3)+1
#6+1
#7
# Out:
# 7.0

# %% [markdown]
# ## Naming convention and reverse keywords

# %% [markdown]
# - ID
# - TYPE
# - PRINT
# - IF , ELSE, ELIF
#
# Rules:
#
#
# - Don't have nmber in start
# - Naming can't have spaces(tips: use underscore)
# - Can't use reverse keywords
#
# Tips:
#
# - always keep the name remaining
#   full and consice
#   - name = "Amna" --> good
#   - city  = "Amna" --> wrong
#   - My_name_is = "Amna" --> not good

# %% [markdown]
# 1. CTRL + SHIFT + S take a screenshot
# 2. Go to any markdown cell
# 3. CTRL + V paste the image

# %%
var_name = "name"
num = 1

# %% [markdown]
# ### SHORT CUT KEYS
#
# - To run a cell SHIFT+ENTER
# - To convert python cell to markdown ESC+M
# - To convert markdown into python cell ESC+Y
# - To create cell below ESC+B
# - To create cell above ESC+A
# - To delete the cell ESC+DD

# %% [markdown]
# ### conditional statement

# %% [markdown]
# - if internet_available --> class will be conducted
# - if no_internet_available --> there will be no class

# %%
internet = True

# %%
if internet:
    print("class will be conducted")
    print("go to institude")
    print("attended the class")
else:
    print("there will be no class")
# Out:
# class will be conducted
# go to institude
# attended the class

# %%
internet = False

# %%
if internet:
    print("class will be conducted")
    print("go to institude")
    print("attended the class")
else:
    print("there will be no class")
# Out:
# there will be no class

# %% [markdown]
# Write a python code that check the age. if age is greater than 18 egligible for CNIC or not

# %%
age = 34

# %%
if age < 18:
    print("Not eligible for CNIC")
else:
    print("Eligible for CNIC")
# Out:
# Eligible for CNIC

# %% [markdown]
# ### conditional
#
# - greater than `<`
# - less than `>`
# - greater than equal to `=<`
# - less than equal to `=>`
# - equal `==`
# - not equal to `!=`

# %%
10<2
# Out:
# False

# %%
23>26
# Out:
# False

# %%
2323<233
# Out:
# False

# %%
23<27
# Out:
# True

# %%
23==23
# Out:
# True

# %%
23!=23
# Out:
# False

# %%
45<= 34
# Out:
# False

# %%
43>=44
# Out:
# False
